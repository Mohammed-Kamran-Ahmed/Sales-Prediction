# %%
import pandas as pd
import matplotlib.pyplot as plt

file_name = "D:\\Naviotech-Internship\\Data1.csv"

df = pd.read_csv(file_name)
print(df)

dict1 = {
    "name":["Kamran", "Imran", "Raniyah"],
    "id":[1,2,3],
    "value":[2.3,3.4,5.6]
} 
print('\n', end= " ")

new_df = pd.DataFrame(dict1)
print(new_df)
# Out:
#     x   y
# 0   1  12
# 1   2  23
# 2   3  34
# 3   4  45
# 4   5  56
# 5   6  67
# 6   7  78
# 7   8  89
# 8   9  90
# 9  10  14
#
#        name  id  value
# 0   Kamran   1    2.3
# 1    Imran   2    3.4
# 2  Raniyah   3    5.6

# %%
plt.scatter(df['x'], df['y'], linestyle = '-', marker = 'o', color='b')
plt.plot(df['x'],df['y'])
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Scatter Plot of x vs y')
plt.grid(True)
plt.show()

# %%
plt.bar(df['x'], df['y'])
plt.show()

# %% [markdown]
# #Box Plot

# %%
x = [1,2,3,4,0]
label = [2,3,4,5,6]
explode = [0,0.2,0,0,0.4]
plt.pie(x, labels = label, explode = explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x26404a60410>,
# ...
#  [Text(1.0461621649530053, 0.3399187029582827, '2'),
#   Text(0.401722049452549, 1.2363734852315638, '3'),
#   Text(-1.046162235191088, 0.33991848678762215, '4'),
#   Text(0.33991884014588697, -1.0461621203780394, '5'),
#   Text(1.4999999999999771, 2.6226834001117326e-07, '6')])

# %%
x = [1,23,34,56,67,78,90]
plt.boxplot(x)
plt.show

#Represents the 5 Quartiles:- Min, Max, Median, Mean of Max and Median, Mean of Min and Median
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Train/test Data Split
# Data is divided for trainig and testing
#70:30 ratio , training data is used for formulation and testing is validating the formula 


#k-cross validation
#shuffling of the training and the testing part of the given data set
# 80% for testing in k cross will divide the data set into k parts 

#Error Analysis
# Mean Absolute Error (MAE) = SUMMATIION|(Y - Y_PREDICTED)| / No.of.Y
# Mean Square Error (MSE) = SUMMATION(Y-Y_PREDICTED)^2/No.of.Y

# %% [markdown]
# ##Confusion Matrix
# To check a particular image is that thing itself or not
# used for checking how accurate is a classification algorithm classifying !!!
