# %%
import nlp
import os
import nltk
from nltk.tokeinze import sent_tokenize, word_tokenize

s = "A person is working along the bank of the river"
print(s)
s = s.lower()
print(s)

words = s.split(" ")
print(words)

words_nltk = nltk.sent_tokenize(s)

# %%
# !pip install nlp
# Out:
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 1.1 MB/s eta 0:00:02
#    ------------------------- -------------- 1.0/1.7 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.7 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 1.8 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#
#    ---------- ----------------------------- 1/4 [tqdm]
#    ---------- ----------------------------- 1/4 [tqdm]
#    ---------- ----------------------------- 1/4 [tqdm]
# ...
